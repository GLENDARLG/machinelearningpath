# %%
import seaborn as sns
vuelos = sns.load_dataset("flights")
vuelos = vuelos.pivot("month", "year", "passengers")
ax = sns.heatmap(vuelos)
# Out:
# /tmp/ipykernel_5923/2335906835.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   vuelos = vuelos.pivot("month", "year", "passengers")

# %%
from platform import python_version

print(python_version())
print('hola mundo')
# Out:
# 3.10.16
# hola mundo

# %%
# no conviene tener mas de 100 celdas

# %%
# %run "prueba.ipynb" # para ejecutar otro notebook de jupiter
# Out:
# /tmp/ipykernel_5923/2335906835.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   vuelos = vuelos.pivot("month", "year", "passengers")
# 3.10.16
# hola mundo
